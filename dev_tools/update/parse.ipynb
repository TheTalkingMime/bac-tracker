# %%
# Requires your BAC version's datapack's data folder
# Requires a completed advancement file named "advancements.json"
# Both of these should be stored in same directory as this script

# IMPORTANT: datapack file format was changed in 1.21
# advancements directory changed to advancement (yeah right)
# would need to change back if backporting to 1.20 and lower

# outputs files needed for tracker's data folder in this same directory

import json, os, csv
from collections import defaultdict

with open('data/advancements.json', 'r') as f:
    adv_data = json.load(f)

# %%
filtered = defaultdict(lambda:[])
advlist = []
for x in list(adv_data.keys()):
    if x == "DataVersion":
        continue
    if x[:17] != 'minecraft:recipes':
        # advlist for building adv_col.csv that later code needs
        advlist.append([x])
        tab, adv = x.split('/')
        filtered[tab].append(adv)

# %%
for tab in filtered:
    print(tab, len(filtered[tab]))

advancements = [
    ['display_name', 'true_name', 'icon']
]

for root in ['minecraft', 'blazeandcave']:
    folder_path = f'data/pack/data/{root}/advancement'
    for tab in os.listdir(folder_path):
        tab_path = os.path.join(folder_path, tab)
        root = folder_path.split('/')[1]
        prefix = f'{root}:{tab}'
        for adv in os.listdir(tab_path):
            true_name = f'{prefix}/{adv[:-5]}'
            adv_path = os.path.join(tab_path, adv)
            # Print next json to open
            print(adv_path)
            try:
                with open(adv_path, 'r') as f:
                    # If this fails Cavinator left a json error (yay!)
                    # Just navigate to the most recent json file and fix
                    data = json.load(f)
                    display_name = data['display']['title']['translate']
                    icon = data['display']['icon']['id'][10:]
            except json.JSONDecodeError:
                raise Exception(f"Invalid JSON in {adv_path}, cavinator missed it, you must fix it.")
            except KeyError:
                display_name = "NOT AN ADVANCEMENT"
            advancements.append([display_name, true_name, icon])

# building adv_col.csv that later code needs
with open('output/adv_col.csv', 'w', newline='') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerows(advlist)

with open('output/advname_to_path.csv', 'w', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter='\t')
    writer.writerows(advancements)

print("Printing Missing Achievements")
# print(adv_data.keys())
for row in advancements[1:]:
    if row[1] not in adv_data:
        print(row[1])
# Out:
# blazeandcave:animal 117
# minecraft:nether 24
# blazeandcave:nether 83
# blazeandcave:farming 57
# minecraft:husbandry 30
# blazeandcave:weaponry 46
# blazeandcave:statistics 60
# blazeandcave:adventure 112
# blazeandcave:enchanting 52
# blazeandcave:redstone 48
# blazeandcave:end 37
# blazeandcave:monsters 77
# blazeandcave:building 108
# blazeandcave:challenges 39
# blazeandcave:potion 26
# blazeandcave:mining 93
# blazeandcave:biomes 64
# blazeandcave:bacap 23
# minecraft:story 16
# minecraft:adventure 44
# blazeandcave:technical 36
# minecraft:end 9
# data/pack/data/minecraft/advancement\adventure\adventuring_time.json
# data/pack/data/minecraft/advancement\adventure\arbalistic.json
# data/pack/data/minecraft/advancement\adventure\avoid_vibration.json
# data/pack/data/minecraft/advancement\adventure\blowback.json
# data/pack/data/minecraft/advancement\adventure\brush_armadillo.json
# data/pack/data/minecraft/advancement\adventure\bullseye.json
# data/pack/data/minecraft/advancement\adventure\crafters_crafting_crafters.json
# data/pack/data/minecraft/advancement\adventure\craft_decorated_pot_using_only_sherds.json
# data/pack/data/minecraft/advancement\adventure\fall_from_world_height.json
# data/pack/data/minecraft/advancement\adventure\hero_of_the_village.json
# data/pack/data/minecraft/advancement\adventure\honey_block_slide.json
# data/pack/data/minecraft/advancement\adventure\kill_all_mobs.json
# data/pack/data/minecraft/advancement\adventure\kill_a_mob.json
# data/pack/data/minecraft/advancement\adventure\kill_mob_near_sculk_catalyst.json
# data/pack/data/minecraft/advancement\adventure\lighten_up.json
# data/pack/data/minecraft/advancement\adventure\lightning_rod_with_villager_no_fire.json
# data/pack/data/minecraft/advancement\adventure\minecraft_trials_edition.json
# data/pack/data/minecraft/advancement\adventure\ol_betsy.json
# data/pack/data/minecraft/advancement\adventure\overoverkill.json
# data/pack/data/minecraft/advancement\adventure\play_jukebox_in_meadows.json
# data/pack/data/minecraft/advancement\adventure\read_power_of_chiseled_bookshelf.json
# data/pack/data/minecraft/advancement\adventure\revaulting.json
# data/pack/data/minecraft/advancement\adventure\root.json
# data/pack/data/minecraft/advancement\adventure\salvage_sherd.json
# data/pack/data/minecraft/advancement\adventure\shoot_arrow.json
# data/pack/data/minecraft/advancement\adventure\sleep_in_bed.json
# data/pack/data/minecraft/advancement\adventure\sniper_duel.json
# data/pack/data/minecraft/advancement\adventure\spyglass_at_dragon.json
# data/pack/data/minecraft/advancement\adventure\spyglass_at_ghast.json
# data/pack/data/minecraft/advancement\adventure\spyglass_at_parrot.json
# data/pack/data/minecraft/advancement\adventure\summon_iron_golem.json
# data/pack/data/minecraft/advancement\adventure\throw_trident.json
# data/pack/data/minecraft/advancement\adventure\totem_of_undying.json
# data/pack/data/minecraft/advancement\adventure\trade.json
# data/pack/data/minecraft/advancement\adventure\trade_at_world_height.json
# data/pack/data/minecraft/advancement\adventure\trim_with_all_exclusive_armor_patterns.json
# data/pack/data/minecraft/advancement\adventure\trim_with_any_armor_pattern.json
# data/pack/data/minecraft/advancement\adventure\two_birds_one_arrow.json
# data/pack/data/minecraft/advancement\adventure\under_lock_and_key.json
# data/pack/data/minecraft/advancement\adventure\very_very_frightening.json
# data/pack/data/minecraft/advancement\adventure\voluntary_exile.json
# data/pack/data/minecraft/advancement\adventure\walk_on_powder_snow_with_leather_boots.json
# data/pack/data/minecraft/advancement\adventure\whos_the_pillager_now.json
# data/pack/data/minecraft/advancement\adventure\who_needs_rockets.json
# data/pack/data/minecraft/advancement\end\dragon_breath.json
# data/pack/data/minecraft/advancement\end\dragon_egg.json
# data/pack/data/minecraft/advancement\end\elytra.json
# data/pack/data/minecraft/advancement\end\enter_end_gateway.json
# data/pack/data/minecraft/advancement\end\find_end_city.json
# data/pack/data/minecraft/advancement\end\kill_dragon.json
# data/pack/data/minecraft/advancement\end\levitate.json
# data/pack/data/minecraft/advancement\end\respawn_dragon.json
# data/pack/data/minecraft/advancement\end\root.json
# data/pack/data/minecraft/advancement\husbandry\allay_deliver_cake_to_note_block.json
# data/pack/data/minecraft/advancement\husbandry\allay_deliver_item_to_player.json
# data/pack/data/minecraft/advancement\husbandry\axolotl_in_a_bucket.json
# data/pack/data/minecraft/advancement\husbandry\balanced_diet.json
# data/pack/data/minecraft/advancement\husbandry\break_diamond_hoe.json
# data/pack/data/minecraft/advancement\husbandry\bred_all_animals.json
# data/pack/data/minecraft/advancement\husbandry\breed_an_animal.json
# data/pack/data/minecraft/advancement\husbandry\complete_catalogue.json
# data/pack/data/minecraft/advancement\husbandry\feed_snifflet.json
# data/pack/data/minecraft/advancement\husbandry\fishy_business.json
# data/pack/data/minecraft/advancement\husbandry\froglights.json
# data/pack/data/minecraft/advancement\husbandry\kill_axolotl_target.json
# data/pack/data/minecraft/advancement\husbandry\leash_all_frog_variants.json
# data/pack/data/minecraft/advancement\husbandry\make_a_sign_glow.json
# data/pack/data/minecraft/advancement\husbandry\obtain_netherite_hoe.json
# data/pack/data/minecraft/advancement\husbandry\obtain_sniffer_egg.json
# data/pack/data/minecraft/advancement\husbandry\plant_any_sniffer_seed.json
# data/pack/data/minecraft/advancement\husbandry\plant_seed.json
# data/pack/data/minecraft/advancement\husbandry\remove_wolf_armor.json
# data/pack/data/minecraft/advancement\husbandry\repair_wolf_armor.json
# data/pack/data/minecraft/advancement\husbandry\ride_a_boat_with_a_goat.json
# data/pack/data/minecraft/advancement\husbandry\root.json
# data/pack/data/minecraft/advancement\husbandry\safely_harvest_honey.json
# data/pack/data/minecraft/advancement\husbandry\silk_touch_nest.json
# data/pack/data/minecraft/advancement\husbandry\tactical_fishing.json
# data/pack/data/minecraft/advancement\husbandry\tadpole_in_a_bucket.json
# data/pack/data/minecraft/advancement\husbandry\tame_an_animal.json
# data/pack/data/minecraft/advancement\husbandry\wax_off.json
# data/pack/data/minecraft/advancement\husbandry\wax_on.json
# data/pack/data/minecraft/advancement\husbandry\whole_pack.json
# data/pack/data/minecraft/advancement\nether\all_effects.json
# data/pack/data/minecraft/advancement\nether\all_potions.json
# data/pack/data/minecraft/advancement\nether\brew_potion.json
# data/pack/data/minecraft/advancement\nether\charge_respawn_anchor.json
# data/pack/data/minecraft/advancement\nether\create_beacon.json
# data/pack/data/minecraft/advancement\nether\create_full_beacon.json
# data/pack/data/minecraft/advancement\nether\distract_piglin.json
# data/pack/data/minecraft/advancement\nether\explore_nether.json
# data/pack/data/minecraft/advancement\nether\fast_travel.json
# data/pack/data/minecraft/advancement\nether\find_bastion.json
# data/pack/data/minecraft/advancement\nether\find_fortress.json
# data/pack/data/minecraft/advancement\nether\get_wither_skull.json
# data/pack/data/minecraft/advancement\nether\loot_bastion.json
# data/pack/data/minecraft/advancement\nether\netherite_armor.json
# data/pack/data/minecraft/advancement\nether\obtain_ancient_debris.json
# data/pack/data/minecraft/advancement\nether\obtain_blaze_rod.json
# data/pack/data/minecraft/advancement\nether\obtain_crying_obsidian.json
# data/pack/data/minecraft/advancement\nether\return_to_sender.json
# data/pack/data/minecraft/advancement\nether\ride_strider.json
# data/pack/data/minecraft/advancement\nether\ride_strider_in_overworld_lava.json
# data/pack/data/minecraft/advancement\nether\root.json
# data/pack/data/minecraft/advancement\nether\summon_wither.json
# data/pack/data/minecraft/advancement\nether\uneasy_alliance.json
# data/pack/data/minecraft/advancement\nether\use_lodestone.json
# data/pack/data/minecraft/advancement\story\cure_zombie_villager.json
# data/pack/data/minecraft/advancement\story\deflect_arrow.json
# data/pack/data/minecraft/advancement\story\enchant_item.json
# data/pack/data/minecraft/advancement\story\enter_the_end.json
# data/pack/data/minecraft/advancement\story\enter_the_nether.json
# data/pack/data/minecraft/advancement\story\follow_ender_eye.json
# data/pack/data/minecraft/advancement\story\form_obsidian.json
# data/pack/data/minecraft/advancement\story\iron_tools.json
# data/pack/data/minecraft/advancement\story\lava_bucket.json
# data/pack/data/minecraft/advancement\story\mine_diamond.json
# data/pack/data/minecraft/advancement\story\mine_stone.json
# data/pack/data/minecraft/advancement\story\obtain_armor.json
# data/pack/data/minecraft/advancement\story\root.json
# data/pack/data/minecraft/advancement\story\shiny_gear.json
# data/pack/data/minecraft/advancement\story\smelt_iron.json
# data/pack/data/minecraft/advancement\story\upgrade_tools.json
# data/pack/data/blazeandcave/advancement\adventure\allayance.json
# data/pack/data/blazeandcave/advancement\adventure\all_chained_up.json
# data/pack/data/blazeandcave/advancement\adventure\and_make_it_double.json
# data/pack/data/blazeandcave/advancement\adventure\awards_ceremony.json
# data/pack/data/blazeandcave/advancement\adventure\a_chiptune_relic.json
# data/pack/data/blazeandcave/advancement\adventure\a_suspicious_advancement.json
# data/pack/data/blazeandcave/advancement\adventure\beethoven.json
# data/pack/data/blazeandcave/advancement\adventure\break_wind.json
# data/pack/data/blazeandcave/advancement\adventure\breeze_suppressor.json
# data/pack/data/blazeandcave/advancement\adventure\brushed_away.json
# data/pack/data/blazeandcave/advancement\adventure\budget_vex.json
# data/pack/data/blazeandcave/advancement\adventure\businessman.json
# data/pack/data/blazeandcave/advancement\adventure\buy_low_sell_high.json
# data/pack/data/blazeandcave/advancement\adventure\chromatic_armory.json
# data/pack/data/blazeandcave/advancement\adventure\coordinated_flair.json
# data/pack/data/blazeandcave/advancement\adventure\core_keeper.json
# data/pack/data/blazeandcave/advancement\adventure\crazy_cat_lady.json
# data/pack/data/blazeandcave/advancement\adventure\deals_off.json
# data/pack/data/blazeandcave/advancement\adventure\diagon_allay.json
# data/pack/data/blazeandcave/advancement\adventure\disc_jockey.json
# data/pack/data/blazeandcave/advancement\adventure\do_you_want_to_trade.json
# data/pack/data/blazeandcave/advancement\adventure\dry_spell.json
# data/pack/data/blazeandcave/advancement\adventure\evelyn_evergreen.json
# data/pack/data/blazeandcave/advancement\adventure\feeling_ill.json
# data/pack/data/blazeandcave/advancement\adventure\filthy_rich.json
# data/pack/data/blazeandcave/advancement\adventure\filthy_stinkin_rich.json
# data/pack/data/blazeandcave/advancement\adventure\florist.json
# data/pack/data/blazeandcave/advancement\adventure\from_under_your_feet.json
# data/pack/data/blazeandcave/advancement\adventure\genesis_of_the_end.json
# data/pack/data/blazeandcave/advancement\adventure\ghostbuster.json
# data/pack/data/blazeandcave/advancement\adventure\good_lookin_treasure.json
# data/pack/data/blazeandcave/advancement\adventure\grave_robber.json
# data/pack/data/blazeandcave/advancement\adventure\guardian_destroyer.json
# data/pack/data/blazeandcave/advancement\adventure\happy_trails.json
# data/pack/data/blazeandcave/advancement\adventure\hard_mode_activated.json
# data/pack/data/blazeandcave/advancement\adventure\heres_johnny.json
# data/pack/data/blazeandcave/advancement\adventure\hey_you_two_should_kiss.json
# data/pack/data/blazeandcave/advancement\adventure\house_of_psychos.json
# data/pack/data/blazeandcave/advancement\adventure\if_only_cats_grew_into_kittens.json
# data/pack/data/blazeandcave/advancement\adventure\im_not_lost_anymore.json
# data/pack/data/blazeandcave/advancement\adventure\its_so_beast_like.json
# data/pack/data/blazeandcave/advancement\adventure\i_am_ravager_hear_me_roar.json
# data/pack/data/blazeandcave/advancement\adventure\i_hereby_dub_thee.json
# data/pack/data/blazeandcave/advancement\adventure\i_just_want_to_make_toast.json
# data/pack/data/blazeandcave/advancement\adventure\jurassic_sniff.json
# data/pack/data/blazeandcave/advancement\adventure\justice.json
# data/pack/data/blazeandcave/advancement\adventure\keys_to_success.json
# data/pack/data/blazeandcave/advancement\adventure\knowledge_is_power.json
# data/pack/data/blazeandcave/advancement\adventure\laser_sharks.json
# data/pack/data/blazeandcave/advancement\adventure\lilypad_hatter.json
# data/pack/data/blazeandcave/advancement\adventure\mapmaker.json
# data/pack/data/blazeandcave/advancement\adventure\mapmakers_table.json
# data/pack/data/blazeandcave/advancement\adventure\map_room.json
# data/pack/data/blazeandcave/advancement\adventure\master_trader.json
# data/pack/data/blazeandcave/advancement\adventure\mold_maker.json
# data/pack/data/blazeandcave/advancement\adventure\monumental.json
# data/pack/data/blazeandcave/advancement\adventure\murderer.json
# data/pack/data/blazeandcave/advancement\adventure\music_to_my_ears.json
# data/pack/data/blazeandcave/advancement\adventure\nerds_never_die.json
# data/pack/data/blazeandcave/advancement\adventure\now_youre_thinking_with_portals.json
# data/pack/data/blazeandcave/advancement\adventure\nyan_sheep.json
# data/pack/data/blazeandcave/advancement\adventure\oh_look_it_dings.json
# data/pack/data/blazeandcave/advancement\adventure\omniscient.json
# data/pack/data/blazeandcave/advancement\adventure\out_of_posts.json
# data/pack/data/blazeandcave/advancement\adventure\overpowered.json
# data/pack/data/blazeandcave/advancement\adventure\picador.json
# data/pack/data/blazeandcave/advancement\adventure\pottery_exhibition.json
# data/pack/data/blazeandcave/advancement\adventure\prime_specimen.json
# data/pack/data/blazeandcave/advancement\adventure\professional.json
# data/pack/data/blazeandcave/advancement\adventure\raiders_of_the_lost_trim.json
# data/pack/data/blazeandcave/advancement\adventure\raidin_master.json
# data/pack/data/blazeandcave/advancement\adventure\rare_candy_shop.json
# data/pack/data/blazeandcave/advancement\adventure\rebuilding_the_oceans.json
# data/pack/data/blazeandcave/advancement\adventure\redemption_arc.json
# data/pack/data/blazeandcave/advancement\adventure\rekt.json
# data/pack/data/blazeandcave/advancement\adventure\retro_future_knight.json
# data/pack/data/blazeandcave/advancement\adventure\riot_shield.json
# data/pack/data/blazeandcave/advancement\adventure\secret_of_the_igloo.json
# data/pack/data/blazeandcave/advancement\adventure\shady_deals.json
# data/pack/data/blazeandcave/advancement\adventure\slenderman.json
# data/pack/data/blazeandcave/advancement\adventure\sound_the_alarm.json
# data/pack/data/blazeandcave/advancement\adventure\spear_fishing.json
# data/pack/data/blazeandcave/advancement\adventure\sponge_miner.json
# data/pack/data/blazeandcave/advancement\adventure\stacked_smither.json
# data/pack/data/blazeandcave/advancement\adventure\superhero_of_the_village.json
# data/pack/data/blazeandcave/advancement\adventure\sus.json
# data/pack/data/blazeandcave/advancement\adventure\the_deep_end.json
# data/pack/data/blazeandcave/advancement\adventure\the_one_and_true_johnny.json
# data/pack/data/blazeandcave/advancement\adventure\the_shielding.json
# data/pack/data/blazeandcave/advancement\adventure\the_sound_of_silence.json
# data/pack/data/blazeandcave/advancement\adventure\the_tribal_villagers.json
# data/pack/data/blazeandcave/advancement\adventure\this_will_be_a_breeze.json
# data/pack/data/blazeandcave/advancement\adventure\tomb_raider.json
# data/pack/data/blazeandcave/advancement\adventure\town_planner.json
# data/pack/data/blazeandcave/advancement\adventure\traveller.json
# data/pack/data/blazeandcave/advancement\adventure\travelling_merchant.json
# data/pack/data/blazeandcave/advancement\adventure\treasure_map.json
# data/pack/data/blazeandcave/advancement\adventure\tricky_treasures.json
# data/pack/data/blazeandcave/advancement\adventure\truffle_worm.json
# data/pack/data/blazeandcave/advancement\adventure\undying_fandom.json
# data/pack/data/blazeandcave/advancement\adventure\vault_hunter.json
# data/pack/data/blazeandcave/advancement\adventure\veteran_of_the_village.json
# data/pack/data/blazeandcave/advancement\adventure\vexingly_hard_to_find.json
# data/pack/data/blazeandcave/advancement\adventure\village_settler.json
# data/pack/data/blazeandcave/advancement\adventure\war_is_coming.json
# data/pack/data/blazeandcave/advancement\adventure\were_being_attacked.json
# data/pack/data/blazeandcave/advancement\adventure\whats_up_doc.json
# data/pack/data/blazeandcave/advancement\adventure\witchcraft.json
# data/pack/data/blazeandcave/advancement\adventure\wololo.json
# data/pack/data/blazeandcave/advancement\adventure\workaholic.json
# data/pack/data/blazeandcave/advancement\adventure\your_daily_fix.json
# data/pack/data/blazeandcave/advancement\adventure\you_are_the_pillager.json
# data/pack/data/blazeandcave/advancement\animal\animal_kingdom.json
# data/pack/data/blazeandcave/advancement\animal\aquarium.json
# data/pack/data/blazeandcave/advancement\animal\are_we_there_yet.json
# data/pack/data/blazeandcave/advancement\animal\armadoggo.json
# data/pack/data/blazeandcave/advancement\animal\artificial_selection.json
# data/pack/data/blazeandcave/advancement\animal\axeolotl.json
# data/pack/data/blazeandcave/advancement\animal\axolittle.json
# data/pack/data/blazeandcave/advancement\animal\axolotl_of_them.json
# data/pack/data/blazeandcave/advancement\animal\a_horse_in_shining_armor.json
# data/pack/data/blazeandcave/advancement\animal\bacon.json
# data/pack/data/blazeandcave/advancement\animal\battle_of_the_bands.json
# data/pack/data/blazeandcave/advancement\animal\beeloons.json
# data/pack/data/blazeandcave/advancement\animal\billy_the_kid.json
# data/pack/data/blazeandcave/advancement\animal\birdkeeper.json
# data/pack/data/blazeandcave/advancement\animal\blackberry_market.json
# data/pack/data/blazeandcave/advancement\animal\blistering_barnacles.json
# data/pack/data/blazeandcave/advancement\animal\bunny_lover.json
# data/pack/data/blazeandcave/advancement\animal\caprymphony.json
# data/pack/data/blazeandcave/advancement\animal\catching_nemo.json
# data/pack/data/blazeandcave/advancement\animal\cephalight.json
# data/pack/data/blazeandcave/advancement\animal\chatterbox.json
# data/pack/data/blazeandcave/advancement\animal\chicken_cooper.json
# data/pack/data/blazeandcave/advancement\animal\colorful_cavalry.json
# data/pack/data/blazeandcave/advancement\animal\cool_kids.json
# data/pack/data/blazeandcave/advancement\animal\cowboy.json
# data/pack/data/blazeandcave/advancement\animal\cow_tipper.json
# data/pack/data/blazeandcave/advancement\animal\delicious_fish.json
# data/pack/data/blazeandcave/advancement\animal\desert_rider.json
# data/pack/data/blazeandcave/advancement\animal\direct_fishing.json
# data/pack/data/blazeandcave/advancement\animal\farmadillo.json
# data/pack/data/blazeandcave/advancement\animal\fashion_statement.json
# data/pack/data/blazeandcave/advancement\animal\feeding_the_chickens.json
# data/pack/data/blazeandcave/advancement\animal\feeling_sheepish.json
# data/pack/data/blazeandcave/advancement\animal\flamboyant_range.json
# data/pack/data/blazeandcave/advancement\animal\flashy_items.json
# data/pack/data/blazeandcave/advancement\animal\foal_play.json
# data/pack/data/blazeandcave/advancement\animal\follow_the_leader.json
# data/pack/data/blazeandcave/advancement\animal\foxy_thievery.json
# data/pack/data/blazeandcave/advancement\animal\fractal.json
# data/pack/data/blazeandcave/advancement\animal\frog_family.json
# data/pack/data/blazeandcave/advancement\animal\fuzzy_feet.json
# data/pack/data/blazeandcave/advancement\animal\getting_into_a_stew.json
# data/pack/data/blazeandcave/advancement\animal\goat_out_of_here.json
# data/pack/data/blazeandcave/advancement\animal\goat_simulator.json
# data/pack/data/blazeandcave/advancement\animal\going_down_the_rabbit_hole.json
# data/pack/data/blazeandcave/advancement\animal\grinding_nemo.json
# data/pack/data/blazeandcave/advancement\animal\have_a_shearful_day.json
# data/pack/data/blazeandcave/advancement\animal\heavy_duty_caravan.json
# data/pack/data/blazeandcave/advancement\animal\hey_look_mom.json
# data/pack/data/blazeandcave/advancement\animal\high_steaks.json
# data/pack/data/blazeandcave/advancement\animal\hive_mind.json
# data/pack/data/blazeandcave/advancement\animal\honey_im_home.json
# data/pack/data/blazeandcave/advancement\animal\horse_armorer.json
# data/pack/data/blazeandcave/advancement\animal\humble_bundle.json
# data/pack/data/blazeandcave/advancement\animal\hump_day.json
# data/pack/data/blazeandcave/advancement\animal\iceologer_shouldve_won.json
# data/pack/data/blazeandcave/advancement\animal\in_a_hole_there_lived_a_rabbit.json
# data/pack/data/blazeandcave/advancement\animal\its_high_noon.json
# data/pack/data/blazeandcave/advancement\animal\just_keeps_going.json
# data/pack/data/blazeandcave/advancement\animal\lead_the_way.json
# data/pack/data/blazeandcave/advancement\animal\live_and_let_dye.json
# data/pack/data/blazeandcave/advancement\animal\llama_festival.json
# data/pack/data/blazeandcave/advancement\animal\llama_llama_duck_king.json
# data/pack/data/blazeandcave/advancement\animal\loud_and_proud.json
# data/pack/data/blazeandcave/advancement\animal\lucky_charm.json
# data/pack/data/blazeandcave/advancement\animal\mary_had_a_little_lamb.json
# data/pack/data/blazeandcave/advancement\animal\master_angler.json
# data/pack/data/blazeandcave/advancement\animal\master_farrier.json
# data/pack/data/blazeandcave/advancement\animal\milkshroom.json
# data/pack/data/blazeandcave/advancement\animal\milk_does_your_body_good.json
# data/pack/data/blazeandcave/advancement\animal\mooshroom_kingdom.json
# data/pack/data/blazeandcave/advancement\animal\mushroom_scientist.json
# data/pack/data/blazeandcave/advancement\animal\nest_quick.json
# data/pack/data/blazeandcave/advancement\animal\not_the_bees.json
# data/pack/data/blazeandcave/advancement\animal\paw_patrol.json
# data/pack/data/blazeandcave/advancement\animal\pig_slaughterer.json
# data/pack/data/blazeandcave/advancement\animal\poacher.json
# data/pack/data/blazeandcave/advancement\animal\pork_chop.json
# data/pack/data/blazeandcave/advancement\animal\puppies_yipe.json
# data/pack/data/blazeandcave/advancement\animal\rabbit_season.json
# data/pack/data/blazeandcave/advancement\animal\rainbow_collection.json
# data/pack/data/blazeandcave/advancement\animal\ram.json
# data/pack/data/blazeandcave/advancement\animal\salmonella_poisoning.json
# data/pack/data/blazeandcave/advancement\animal\save_the_turtles.json
# data/pack/data/blazeandcave/advancement\animal\screaming_milk.json
# data/pack/data/blazeandcave/advancement\animal\scuttler.json
# data/pack/data/blazeandcave/advancement\animal\sheariously.json
# data/pack/data/blazeandcave/advancement\animal\shoe_shed.json
# data/pack/data/blazeandcave/advancement\animal\silence_of_the_lambs.json
# data/pack/data/blazeandcave/advancement\animal\snow_fox_64.json
# data/pack/data/blazeandcave/advancement\animal\someones_been_here_before.json
# data/pack/data/blazeandcave/advancement\animal\so_good.json
# data/pack/data/blazeandcave/advancement\animal\so_hungry_i_could_eat_a_horse.json
# data/pack/data/blazeandcave/advancement\animal\so_i_got_that_going_for_me.json
# data/pack/data/blazeandcave/advancement\animal\stay_calmer.json
# data/pack/data/blazeandcave/advancement\animal\super_mooshroom.json
# data/pack/data/blazeandcave/advancement\animal\sushi.json
# data/pack/data/blazeandcave/advancement\animal\swine_sailing.json
# data/pack/data/blazeandcave/advancement\animal\thanks_a_lotl.json
# data/pack/data/blazeandcave/advancement\animal\theyre_breeding_like_rabbits.json
# data/pack/data/blazeandcave/advancement\animal\the_high_road.json
# data/pack/data/blazeandcave/advancement\animal\tickle_time.json
# data/pack/data/blazeandcave/advancement\animal\totally_not_an_afk_fisher.json
# data/pack/data/blazeandcave/advancement\animal\treasure_hunter.json
# data/pack/data/blazeandcave/advancement\animal\tropical_collection.json
# data/pack/data/blazeandcave/advancement\animal\true_cow_tipper.json
# data/pack/data/blazeandcave/advancement\animal\turtle_army.json
# data/pack/data/blazeandcave/advancement\animal\turtle_soldier.json
# data/pack/data/blazeandcave/advancement\animal\what_a_piece_of_junk.json
# data/pack/data/blazeandcave/advancement\animal\what_does_the_fox_say.json
# data/pack/data/blazeandcave/advancement\animal\when_pigs_used_to_fly.json
# data/pack/data/blazeandcave/advancement\animal\wheres_the_honey_lebowski.json
# data/pack/data/blazeandcave/advancement\animal\which_came_first.json
# data/pack/data/blazeandcave/advancement\animal\winnie_the_pooh.json
# data/pack/data/blazeandcave/advancement\animal\wooly.json
# data/pack/data/blazeandcave/advancement\animal\ya_like_jazz.json
# data/pack/data/blazeandcave/advancement\animal\you_lead_ill_follow.json
# data/pack/data/blazeandcave/advancement\bacap\advancement_legend.json
# data/pack/data/blazeandcave/advancement\bacap\adventure_milestone.json
# data/pack/data/blazeandcave/advancement\bacap\animal_milestone.json
# data/pack/data/blazeandcave/advancement\bacap\biomes_milestone.json
# data/pack/data/blazeandcave/advancement\bacap\building_milestone.json
# data/pack/data/blazeandcave/advancement\bacap\challenges_milestone.json
# data/pack/data/blazeandcave/advancement\bacap\enchanting_milestone.json
# data/pack/data/blazeandcave/advancement\bacap\end_milestone.json
# data/pack/data/blazeandcave/advancement\bacap\farming_milestone.json
# data/pack/data/blazeandcave/advancement\bacap\getting_wood.json
# data/pack/data/blazeandcave/advancement\bacap\mining_milestone.json
# data/pack/data/blazeandcave/advancement\bacap\monsters_milestone.json
# data/pack/data/blazeandcave/advancement\bacap\nether_milestone.json
# data/pack/data/blazeandcave/advancement\bacap\potion_milestone.json
# data/pack/data/blazeandcave/advancement\bacap\redstone_milestone.json
# data/pack/data/blazeandcave/advancement\bacap\root.json
# data/pack/data/blazeandcave/advancement\bacap\statistics_milestone.json
# data/pack/data/blazeandcave/advancement\bacap\time_to_chop.json
# data/pack/data/blazeandcave/advancement\bacap\time_to_dig.json
# data/pack/data/blazeandcave/advancement\bacap\time_to_farm.json
# data/pack/data/blazeandcave/advancement\bacap\time_to_mine.json
# data/pack/data/blazeandcave/advancement\bacap\time_to_strike.json
# data/pack/data/blazeandcave/advancement\bacap\weaponry_milestone.json
# data/pack/data/blazeandcave/advancement\biomes\ahoy.json
# data/pack/data/blazeandcave/advancement\biomes\atlantis.json
# data/pack/data/blazeandcave/advancement\biomes\bamboom.json
# data/pack/data/blazeandcave/advancement\biomes\barbearian.json
# data/pack/data/blazeandcave/advancement\biomes\boatception.json
# data/pack/data/blazeandcave/advancement\biomes\boaty_mcboatface.json
# data/pack/data/blazeandcave/advancement\biomes\captain_america.json
# data/pack/data/blazeandcave/advancement\biomes\cargo_carrier.json
# data/pack/data/blazeandcave/advancement\biomes\cold_feet.json
# data/pack/data/blazeandcave/advancement\biomes\construction_worker.json
# data/pack/data/blazeandcave/advancement\biomes\dive_bomb.json
# data/pack/data/blazeandcave/advancement\biomes\dolphin_dasher.json
# data/pack/data/blazeandcave/advancement\biomes\echolocation.json
# data/pack/data/blazeandcave/advancement\biomes\edge_of_the_jungle.json
# data/pack/data/blazeandcave/advancement\biomes\enchanted_forest.json
# data/pack/data/blazeandcave/advancement\biomes\everybody_loves_ice.json
# data/pack/data/blazeandcave/advancement\biomes\eyeball_forest.json
# data/pack/data/blazeandcave/advancement\biomes\fake_copper.json
# data/pack/data/blazeandcave/advancement\biomes\flipper.json
# data/pack/data/blazeandcave/advancement\biomes\flower_power.json
# data/pack/data/blazeandcave/advancement\biomes\for_you_my_sweet.json
# data/pack/data/blazeandcave/advancement\biomes\free_diver.json
# data/pack/data/blazeandcave/advancement\biomes\heart_breaker.json
# data/pack/data/blazeandcave/advancement\biomes\high_feet.json
# data/pack/data/blazeandcave/advancement\biomes\in_a_pickle.json
# data/pack/data/blazeandcave/advancement\biomes\just_a_sample.json
# data/pack/data/blazeandcave/advancement\biomes\just_keep_swimming.json
# data/pack/data/blazeandcave/advancement\biomes\kilometre_walk.json
# data/pack/data/blazeandcave/advancement\biomes\kung_fu_panda.json
# data/pack/data/blazeandcave/advancement\biomes\lion_hunter.json
# data/pack/data/blazeandcave/advancement\biomes\moskstraumen.json
# data/pack/data/blazeandcave/advancement\biomes\no_reefing.json
# data/pack/data/blazeandcave/advancement\biomes\one_with_the_forest.json
# data/pack/data/blazeandcave/advancement\biomes\overgrown.json
# data/pack/data/blazeandcave/advancement\biomes\pale_in_comparison.json
# data/pack/data/blazeandcave/advancement\biomes\pandamonium.json
# data/pack/data/blazeandcave/advancement\biomes\powder_full.json
# data/pack/data/blazeandcave/advancement\biomes\pretty_in_pink.json
# data/pack/data/blazeandcave/advancement\biomes\pushed_around.json
# data/pack/data/blazeandcave/advancement\biomes\qinling.json
# data/pack/data/blazeandcave/advancement\biomes\resinance.json
# data/pack/data/blazeandcave/advancement\biomes\root.json
# data/pack/data/blazeandcave/advancement\biomes\simba.json
# data/pack/data/blazeandcave/advancement\biomes\sleep_with_the_fishes.json
# data/pack/data/blazeandcave/advancement\biomes\smooth_operator.json
# data/pack/data/blazeandcave/advancement\biomes\so_long_and_thanks_for_all_the_fish.json
# data/pack/data/blazeandcave/advancement\biomes\spike_ice.json
# data/pack/data/blazeandcave/advancement\biomes\tarzan.json
# data/pack/data/blazeandcave/advancement\biomes\ten_thousand_blocks.json
# data/pack/data/blazeandcave/advancement\biomes\theres_a_zombie_on_the_lawn.json
# data/pack/data/blazeandcave/advancement\biomes\the_great_blocky_reef.json
# data/pack/data/blazeandcave/advancement\biomes\the_mighty_jungle.json
# data/pack/data/blazeandcave/advancement\biomes\the_sea_calls_you.json
# data/pack/data/blazeandcave/advancement\biomes\thick_ice.json
# data/pack/data/blazeandcave/advancement\biomes\thin_ice.json
# data/pack/data/blazeandcave/advancement\biomes\this_snow_is_snowier.json
# data/pack/data/blazeandcave/advancement\biomes\titanic.json
# data/pack/data/blazeandcave/advancement\biomes\top_of_the_world.json
# data/pack/data/blazeandcave/advancement\biomes\voyage.json
# data/pack/data/blazeandcave/advancement\biomes\warm_feet.json
# data/pack/data/blazeandcave/advancement\biomes\were_going_on_a_bear_hunt.json
# data/pack/data/blazeandcave/advancement\biomes\wet_feet.json
# data/pack/data/blazeandcave/advancement\biomes\x_marks_the_spot.json
# data/pack/data/blazeandcave/advancement\biomes\zoologist.json
# data/pack/data/blazeandcave/advancement\building\agent_smithing_table.json
# data/pack/data/blazeandcave/advancement\building\ah_my_old_enemy.json
# data/pack/data/blazeandcave/advancement\building\and_open.json
# data/pack/data/blazeandcave/advancement\building\armor_display.json
# data/pack/data/blazeandcave/advancement\building\art_gallery.json
# data/pack/data/blazeandcave/advancement\building\a_good_start.json
# data/pack/data/blazeandcave/advancement\building\a_masterpiece.json
# data/pack/data/blazeandcave/advancement\building\bamboozled.json
# data/pack/data/blazeandcave/advancement\building\barking_mad.json
# data/pack/data/blazeandcave/advancement\building\barrel_rider.json
# data/pack/data/blazeandcave/advancement\building\blackstonehenge.json
# data/pack/data/blazeandcave/advancement\building\blast_it.json
# data/pack/data/blazeandcave/advancement\building\bricks.json
# data/pack/data/blazeandcave/advancement\building\bubble_bubble_toil_and_trouble.json
# data/pack/data/blazeandcave/advancement\building\built_on_sand_set_in_stone.json
# data/pack/data/blazeandcave/advancement\building\bulbous.json
# data/pack/data/blazeandcave/advancement\building\camping_out.json
# data/pack/data/blazeandcave/advancement\building\cerulean.json
# data/pack/data/blazeandcave/advancement\building\change_of_sheets.json
# data/pack/data/blazeandcave/advancement\building\cherry_bomb.json
# data/pack/data/blazeandcave/advancement\building\classic_pocket_edition_block.json
# data/pack/data/blazeandcave/advancement\building\classy_glassy.json
# data/pack/data/blazeandcave/advancement\building\clay_dough.json
# data/pack/data/blazeandcave/advancement\building\colors_of_the_wind.json
# data/pack/data/blazeandcave/advancement\building\concrete_evidence.json
# data/pack/data/blazeandcave/advancement\building\crazy_walls.json
# data/pack/data/blazeandcave/advancement\building\creepers_and_withers.json
# data/pack/data/blazeandcave/advancement\building\cut_in_half.json
# data/pack/data/blazeandcave/advancement\building\deepslate_conspiracy.json
# data/pack/data/blazeandcave/advancement\building\delicious_hot_schmoes.json
# data/pack/data/blazeandcave/advancement\building\electric.json
# data/pack/data/blazeandcave/advancement\building\elmer_mudd.json
# data/pack/data/blazeandcave/advancement\building\en_garde.json
# data/pack/data/blazeandcave/advancement\building\expensive.json
# data/pack/data/blazeandcave/advancement\building\fake_fortress.json
# data/pack/data/blazeandcave/advancement\building\fake_monument.json
# data/pack/data/blazeandcave/advancement\building\fake_stronghold.json
# data/pack/data/blazeandcave/advancement\building\festival_of_lights.json
# data/pack/data/blazeandcave/advancement\building\fluorescent.json
# data/pack/data/blazeandcave/advancement\building\fruit_of_the_looms.json
# data/pack/data/blazeandcave/advancement\building\glowing.json
# data/pack/data/blazeandcave/advancement\building\grass_type.json
# data/pack/data/blazeandcave/advancement\building\greek_art_decor.json
# data/pack/data/blazeandcave/advancement\building\halloween.json
# data/pack/data/blazeandcave/advancement\building\hanging_around.json
# data/pack/data/blazeandcave/advancement\building\happy_birthday.json
# data/pack/data/blazeandcave/advancement\building\harry_potter.json
# data/pack/data/blazeandcave/advancement\building\help_ive_been_framed.json
# data/pack/data/blazeandcave/advancement\building\hot_tub.json
# data/pack/data/blazeandcave/advancement\building\insomniac.json
# data/pack/data/blazeandcave/advancement\building\its_a_sign.json
# data/pack/data/blazeandcave/advancement\building\its_a_trap.json
# data/pack/data/blazeandcave/advancement\building\its_original_form.json
# data/pack/data/blazeandcave/advancement\building\i_dont_like_sand.json
# data/pack/data/blazeandcave/advancement\building\jailhouse_block.json
# data/pack/data/blazeandcave/advancement\building\ladder_climbers_inc.json
# data/pack/data/blazeandcave/advancement\building\let_there_be_light.json
# data/pack/data/blazeandcave/advancement\building\living_dummy.json
# data/pack/data/blazeandcave/advancement\building\lost_its_bark.json
# data/pack/data/blazeandcave/advancement\building\mangrove_master.json
# data/pack/data/blazeandcave/advancement\building\mannequin.json
# data/pack/data/blazeandcave/advancement\building\master_logger.json
# data/pack/data/blazeandcave/advancement\building\no_banner_only_color.json
# data/pack/data/blazeandcave/advancement\building\no_chain_no_gain.json
# data/pack/data/blazeandcave/advancement\building\one_pickle_two_pickle_sea_pickle_four.json
# data/pack/data/blazeandcave/advancement\building\pale_gardener.json
# data/pack/data/blazeandcave/advancement\building\pane_in_the_glass.json
# data/pack/data/blazeandcave/advancement\building\pathways.json
# data/pack/data/blazeandcave/advancement\building\pot_planter.json
# data/pack/data/blazeandcave/advancement\building\prepare_to_meet_your_loom.json
# data/pack/data/blazeandcave/advancement\building\professor_birch.json
# data/pack/data/blazeandcave/advancement\building\professor_dark_oak.json
# data/pack/data/blazeandcave/advancement\building\professor_oak.json
# data/pack/data/blazeandcave/advancement\building\rainbow_dreams.json
# data/pack/data/blazeandcave/advancement\building\rainbow_sand.json
# data/pack/data/blazeandcave/advancement\building\raise_the_flag.json
# data/pack/data/blazeandcave/advancement\building\rock_collection.json
# data/pack/data/blazeandcave/advancement\building\rock_polish.json
# data/pack/data/blazeandcave/advancement\building\root.json
# data/pack/data/blazeandcave/advancement\building\setting_up_the_mood.json
# data/pack/data/blazeandcave/advancement\building\sharpening_station.json
# data/pack/data/blazeandcave/advancement\building\shelf_expression.json
# data/pack/data/blazeandcave/advancement\building\shroom_lightyear.json
# data/pack/data/blazeandcave/advancement\building\sign_off.json
# data/pack/data/blazeandcave/advancement\building\skyblock.json
# data/pack/data/blazeandcave/advancement\building\slabs_for_days.json
# data/pack/data/blazeandcave/advancement\building\smooth_dude.json
# data/pack/data/blazeandcave/advancement\building\spawn_camping.json
# data/pack/data/blazeandcave/advancement\building\spruce_lee.json
# data/pack/data/blazeandcave/advancement\building\stairs_no.json
# data/pack/data/blazeandcave/advancement\building\stationary_storage.json
# data/pack/data/blazeandcave/advancement\building\stripper.json
# data/pack/data/blazeandcave/advancement\building\stuck_in_the_mud.json
# data/pack/data/blazeandcave/advancement\building\the_acacia_king.json
# data/pack/data/blazeandcave/advancement\building\the_glazed_terracotta_army.json
# data/pack/data/blazeandcave/advancement\building\the_jungler.json
# data/pack/data/blazeandcave/advancement\building\the_rainbow_you_always_wanted.json
# data/pack/data/blazeandcave/advancement\building\the_ritual_begins.json
# data/pack/data/blazeandcave/advancement\building\the_terracotta_army.json
# data/pack/data/blazeandcave/advancement\building\the_walls.json
# data/pack/data/blazeandcave/advancement\building\torched.json
# data/pack/data/blazeandcave/advancement\building\translucence.json
# data/pack/data/blazeandcave/advancement\building\tuff_stuff.json
# data/pack/data/blazeandcave/advancement\building\washing_machine.json
# data/pack/data/blazeandcave/advancement\building\what_a_pane.json
# data/pack/data/blazeandcave/advancement\building\writers_block.json
# data/pack/data/blazeandcave/advancement\building\yay_i_got_my_wood.json
# data/pack/data/blazeandcave/advancement\building\your_door_was_locked.json
# data/pack/data/blazeandcave/advancement\challenges\abyss_lord.json
# data/pack/data/blazeandcave/advancement\challenges\ad_astra.json
# data/pack/data/blazeandcave/advancement\challenges\all_the_blocks.json
# data/pack/data/blazeandcave/advancement\challenges\all_the_items.json
# data/pack/data/blazeandcave/advancement\challenges\a_million_blocks_away.json
# data/pack/data/blazeandcave/advancement\challenges\biological_warfare.json
# data/pack/data/blazeandcave/advancement\challenges\constellation.json
# data/pack/data/blazeandcave/advancement\challenges\creepergeddon.json
# data/pack/data/blazeandcave/advancement\challenges\death_from_all.json
# data/pack/data/blazeandcave/advancement\challenges\dragon_army.json
# data/pack/data/blazeandcave/advancement\challenges\dragon_vs_dragon_ii_electric_boogaloo.json
# data/pack/data/blazeandcave/advancement\challenges\dragon_vs_wither_the_pre_sequel.json
# data/pack/data/blazeandcave/advancement\challenges\endergeddon.json
# data/pack/data/blazeandcave/advancement\challenges\explorer_of_worlds.json
# data/pack/data/blazeandcave/advancement\challenges\farlander.json
# data/pack/data/blazeandcave/advancement\challenges\global_vaccination.json
# data/pack/data/blazeandcave/advancement\challenges\hearts_of_the_stack.json
# data/pack/data/blazeandcave/advancement\challenges\highway_to_hell.json
# data/pack/data/blazeandcave/advancement\challenges\immortal.json
# data/pack/data/blazeandcave/advancement\challenges\im_in_space.json
# data/pack/data/blazeandcave/advancement\challenges\i_am_loot.json
# data/pack/data/blazeandcave/advancement\challenges\nuclear_fusion.json
# data/pack/data/blazeandcave/advancement\challenges\overwarden.json
# data/pack/data/blazeandcave/advancement\challenges\poglin.json
# data/pack/data/blazeandcave/advancement\challenges\potion_master.json
# data/pack/data/blazeandcave/advancement\challenges\riddle_me_this.json
# data/pack/data/blazeandcave/advancement\challenges\rise_of_the_skeletons.json
# data/pack/data/blazeandcave/advancement\challenges\root.json
# data/pack/data/blazeandcave/advancement\challenges\stack_all_the_blocks.json
# data/pack/data/blazeandcave/advancement\challenges\stack_all_the_items.json
# data/pack/data/blazeandcave/advancement\challenges\stockbroker.json
# data/pack/data/blazeandcave/advancement\challenges\telescopic.json
# data/pack/data/blazeandcave/advancement\challenges\the_devils_distance.json
# data/pack/data/blazeandcave/advancement\challenges\the_perfect_run.json
# data/pack/data/blazeandcave/advancement\challenges\the_world_is_ending.json
# data/pack/data/blazeandcave/advancement\challenges\ultimate_enchanter.json
# data/pack/data/blazeandcave/advancement\challenges\warlock.json
# data/pack/data/blazeandcave/advancement\challenges\were_in_the_endgame_now.json
# data/pack/data/blazeandcave/advancement\challenges\zombie_apocalypse.json
# data/pack/data/blazeandcave/advancement\enchanting\armor_for_the_masses.json
# data/pack/data/blazeandcave/advancement\enchanting\a_rather_pointy_fence_post.json
# data/pack/data/blazeandcave/advancement\enchanting\bane_of_one_shotting_spiders.json
# data/pack/data/blazeandcave/advancement\enchanting\baron_of_blacksmiths.json
# data/pack/data/blazeandcave/advancement\enchanting\boomerang.json
# data/pack/data/blazeandcave/advancement\enchanting\bow_down_to_me.json
# data/pack/data/blazeandcave/advancement\enchanting\complete_enchanter.json
# data/pack/data/blazeandcave/advancement\enchanting\curses.json
# data/pack/data/blazeandcave/advancement\enchanting\do_a_barrel_roll.json
# data/pack/data/blazeandcave/advancement\enchanting\fiery.json
# data/pack/data/blazeandcave/advancement\enchanting\fortunate_son.json
# data/pack/data/blazeandcave/advancement\enchanting\god_of_thunder.json
# data/pack/data/blazeandcave/advancement\enchanting\gotta_go_fast.json
# data/pack/data/blazeandcave/advancement\enchanting\handmade_blinding.json
# data/pack/data/blazeandcave/advancement\enchanting\heavy_metal.json
# data/pack/data/blazeandcave/advancement\enchanting\ill_be_back.json
# data/pack/data/blazeandcave/advancement\enchanting\knocking_your_socks_off.json
# data/pack/data/blazeandcave/advancement\enchanting\let_it_go.json
# data/pack/data/blazeandcave/advancement\enchanting\librarian.json
# data/pack/data/blazeandcave/advancement\enchanting\like_a_cat.json
# data/pack/data/blazeandcave/advancement\enchanting\like_a_ninja.json
# data/pack/data/blazeandcave/advancement\enchanting\mace_windu.json
# data/pack/data/blazeandcave/advancement\enchanting\machine_bow.json
# data/pack/data/blazeandcave/advancement\enchanting\magical_stockpile.json
# data/pack/data/blazeandcave/advancement\enchanting\master_arbalist.json
# data/pack/data/blazeandcave/advancement\enchanting\master_armorer.json
# data/pack/data/blazeandcave/advancement\enchanting\master_axeman.json
# data/pack/data/blazeandcave/advancement\enchanting\master_digger.json
# data/pack/data/blazeandcave/advancement\enchanting\master_enchanter.json
# data/pack/data/blazeandcave/advancement\enchanting\master_farmer.json
# data/pack/data/blazeandcave/advancement\enchanting\master_fisher.json
# data/pack/data/blazeandcave/advancement\enchanting\master_knight.json
# data/pack/data/blazeandcave/advancement\enchanting\master_macerator.json
# data/pack/data/blazeandcave/advancement\enchanting\master_miner.json
# data/pack/data/blazeandcave/advancement\enchanting\master_sniper.json
# data/pack/data/blazeandcave/advancement\enchanting\master_tridenteer.json
# data/pack/data/blazeandcave/advancement\enchanting\needle_sharp.json
# data/pack/data/blazeandcave/advancement\enchanting\newtons_flaming_laser_sword.json
# data/pack/data/blazeandcave/advancement\enchanting\overkill.json
# data/pack/data/blazeandcave/advancement\enchanting\over_overkill.json
# data/pack/data/blazeandcave/advancement\enchanting\pick_like_silk.json
# data/pack/data/blazeandcave/advancement\enchanting\root.json
# data/pack/data/blazeandcave/advancement\enchanting\scuba_gear.json
# data/pack/data/blazeandcave/advancement\enchanting\shotbow.json
# data/pack/data/blazeandcave/advancement\enchanting\silent_but_deadly.json
# data/pack/data/blazeandcave/advancement\enchanting\super_efficient.json
# data/pack/data/blazeandcave/advancement\enchanting\this_name_sounds_cooler.json
# data/pack/data/blazeandcave/advancement\enchanting\to_infinity_and_beyond.json
# data/pack/data/blazeandcave/advancement\enchanting\unbreakable.json
# data/pack/data/blazeandcave/advancement\enchanting\undead_slayer.json
# data/pack/data/blazeandcave/advancement\enchanting\whack_a_mole.json
# data/pack/data/blazeandcave/advancement\enchanting\zeus.json
# data/pack/data/blazeandcave/advancement\end\anti_gravity_generator.json
# data/pack/data/blazeandcave/advancement\end\a_wizards_breakfast.json
# data/pack/data/blazeandcave/advancement\end\cow_jumped_over_the_moon.json
# data/pack/data/blazeandcave/advancement\end\dimension_penetration.json
# data/pack/data/blazeandcave/advancement\end\divers_dozen.json
# data/pack/data/blazeandcave/advancement\end\dogfight.json
# data/pack/data/blazeandcave/advancement\end\dragon_shield.json
# data/pack/data/blazeandcave/advancement\end\dragon_vs_dragon.json
# data/pack/data/blazeandcave/advancement\end\end_bricks.json
# data/pack/data/blazeandcave/advancement\end\event_horizon.json
# data/pack/data/blazeandcave/advancement\end\extrabiologist.json
# data/pack/data/blazeandcave/advancement\end\for_mother_clarence.json
# data/pack/data/blazeandcave/advancement\end\getting_chorus.json
# data/pack/data/blazeandcave/advancement\end\good_luck_getting_this_one.json
# data/pack/data/blazeandcave/advancement\end\im_coming_back_murph.json
# data/pack/data/blazeandcave/advancement\end\in_your_face_neil_armstrong.json
# data/pack/data/blazeandcave/advancement\end\no_dont_let_me_leave_murph.json
# data/pack/data/blazeandcave/advancement\end\off_with_his_head.json
# data/pack/data/blazeandcave/advancement\end\organizational_wizard.json
# data/pack/data/blazeandcave/advancement\end\portable_storage.json
# data/pack/data/blazeandcave/advancement\end\purpurfect.json
# data/pack/data/blazeandcave/advancement\end\ring_of_the_end.json
# data/pack/data/blazeandcave/advancement\end\rocketman.json
# data/pack/data/blazeandcave/advancement\end\shouldnt_my_shield_levitate_too.json
# data/pack/data/blazeandcave/advancement\end\shulker_breaker.json
# data/pack/data/blazeandcave/advancement\end\sky_high.json
# data/pack/data/blazeandcave/advancement\end\somewhere_over_the_rainbow.json
# data/pack/data/blazeandcave/advancement\end\some_breakthrough.json
# data/pack/data/blazeandcave/advancement\end\the_actual_end.json
# data/pack/data/blazeandcave/advancement\end\the_beginning.json
# data/pack/data/blazeandcave/advancement\end\the_point_of_no_return.json
# data/pack/data/blazeandcave/advancement\end\the_start_of_something.json
# data/pack/data/blazeandcave/advancement\end\the_void_frogs.json
# data/pack/data/blazeandcave/advancement\end\uh_houston_we_have_a_problem.json
# data/pack/data/blazeandcave/advancement\end\unending_hell.json
# data/pack/data/blazeandcave/advancement\end\void_walker.json
# data/pack/data/blazeandcave/advancement\end\what_for.json
# data/pack/data/blazeandcave/advancement\farming\24_carrot_gold.json
# data/pack/data/blazeandcave/advancement\farming\an_amazing_story.json
# data/pack/data/blazeandcave/advancement\farming\an_apple_a_day.json
# data/pack/data/blazeandcave/advancement\farming\aquatic_biofuel.json
# data/pack/data/blazeandcave/advancement\farming\a_gluttonous_diet.json
# data/pack/data/blazeandcave/advancement\farming\a_mangrove_grove.json
# data/pack/data/blazeandcave/advancement\farming\bake_bread.json
# data/pack/data/blazeandcave/advancement\farming\bapple.json
# data/pack/data/blazeandcave/advancement\farming\berry_nice.json
# data/pack/data/blazeandcave/advancement\farming\care_for_the_environment.json
# data/pack/data/blazeandcave/advancement\farming\castaway.json
# data/pack/data/blazeandcave/advancement\farming\combine_harvester.json
# data/pack/data/blazeandcave/advancement\farming\come_to_the_countryside.json
# data/pack/data/blazeandcave/advancement\farming\die_potato.json
# data/pack/data/blazeandcave/advancement\farming\disen_berry_berry_bad.json
# data/pack/data/blazeandcave/advancement\farming\ecologist.json
# data/pack/data/blazeandcave/advancement\farming\foliage.json
# data/pack/data/blazeandcave/advancement\farming\full_stomach.json
# ...
# pack:farming/24_carrot_gold
# pack:farming/an_amazing_story
# pack:farming/an_apple_a_day
# pack:farming/aquatic_biofuel
# pack:farming/a_gluttonous_diet
# pack:farming/a_mangrove_grove
# pack:farming/bake_bread
# pack:farming/bapple
# pack:farming/berry_nice
# pack:farming/care_for_the_environment
# pack:farming/castaway
# pack:farming/combine_harvester
# pack:farming/come_to_the_countryside
# pack:farming/die_potato
# pack:farming/disen_berry_berry_bad
# pack:farming/ecologist
# pack:farming/foliage
# pack:farming/full_stomach
# pack:farming/hay_there
# pack:farming/hot_chocolate
# pack:farming/im_gonna_be_sick
# pack:farming/its_a_cactus
# pack:farming/its_full_of_ink
# pack:farming/its_where_nutella_comes_from
# pack:farming/kelp_me
# pack:farming/meat_lovers
# pack:farming/mega_mushroom
# pack:farming/me_love_cookie
# pack:farming/mushroom_mushroom
# pack:farming/must_be_your_birthday
# pack:farming/naturally_carved
# pack:farming/natural_fertiliser
# pack:farming/not_today
# pack:farming/olaf
# pack:farming/one_course_meal
# pack:farming/pumpa_kungen
# pack:farming/root
# pack:farming/scientific_inaccuracy
# pack:farming/shrooms
# pack:farming/souperman
# pack:farming/spikey
# pack:farming/squid_game
# pack:farming/sugar_sugar
# pack:farming/suspicious_looking_stew
# pack:farming/the_garbage_will_do
# pack:farming/the_lie
# pack:farming/the_meloncholy_dane
# pack:farming/the_melon_the_melon_the_melon
# pack:farming/the_pie
# pack:farming/trimming_the_treetops
# pack:farming/ultra_hardcore
# pack:farming/undersea_gardener
# pack:farming/unmasked
# pack:farming/vegetarian
# pack:farming/whats_new_with_composting
# pack:farming/write_your_thoughts
# pack:farming/yay_deadbush
# pack:mining/9_to_5
# pack:mining/amethyst_miner
# pack:mining/aww_it_broke
# pack:mining/a_shiny_treat
# pack:mining/blackout
# pack:mining/blind_as_a_bat
# pack:mining/bling_bling_gone
# pack:mining/bonfire_night
# pack:mining/bottom_to_top
# pack:mining/budget_channeling
# pack:mining/bulldozer
# pack:mining/called_shot
# pack:mining/chestful_of_cobblestone
# pack:mining/coal_miner
# pack:mining/copper_miner
# pack:mining/death_pointer
# pack:mining/deep_slate_nine
# pack:mining/diamonds_to_you
# pack:mining/diamond_clad
# pack:mining/diamond_miner
# pack:mining/diam_oh_wait_no
# pack:mining/dont_come_a_copper
# pack:mining/dripstone_drop
# pack:mining/dungeons_and_spawners
# pack:mining/echonomy
# pack:mining/eeuuwww
# pack:mining/emerald_miner
# pack:mining/even_moar_tools
# pack:mining/fallen_kingdom
# pack:mining/flint_miner
# pack:mining/fossil_fuel
# pack:mining/frigid_diversions
# pack:mining/galileo_figaro
# pack:mining/gi_geode
# pack:mining/gold_mine
# pack:mining/gold_miner
# pack:mining/gold_rush
# pack:mining/good_for_your_bones
# pack:mining/grate_expectations
# pack:mining/heart_of_darkness
# pack:mining/hot_topic
# pack:mining/iconic_merchandising_prop
# pack:mining/iggy
# pack:mining/iron_man
# pack:mining/iron_miner
# pack:mining/i_yearned_for_the_mines
# pack:mining/lapis_lazuli_miner
# pack:mining/leaflet_drop
# pack:mining/lichen_subscribe
# pack:mining/living_like_kings
# pack:mining/lucky_break
# pack:mining/lush_hour
# pack:mining/master_coal_miner
# pack:mining/master_copper_miner
# pack:mining/master_diamond_miner
# pack:mining/master_gold_miner
# pack:mining/master_iron_miner
# pack:mining/meet_the_flintstones
# pack:mining/mineral_collection
# pack:mining/moar_broken_tools
# pack:mining/moar_tools
# pack:mining/moss_maker
# pack:mining/mr_bean
# pack:mining/my_work_here_is_done
# pack:mining/nananananananana
# pack:mining/not_chicken_mcnuggets
# pack:mining/obsidian_miner
# pack:mining/oresome
# pack:mining/particle_fan
# pack:mining/pixel_perfect
# pack:mining/redstone_miner
# pack:mining/renewable_energy
# pack:mining/rest_in_pickaxes
# pack:mining/rock_bottom
# pack:mining/root
# pack:mining/seeing_red
# pack:mining/shriek_forever_after
# pack:mining/sly_copper_the_copper_heist
# pack:mining/smokin_hot
# pack:mining/spelunker
# pack:mining/stabcraft
# pack:mining/steals_on_wheels
# pack:mining/strike_a_light
# pack:mining/thats_the_point
# pack:mining/the_mistake
# pack:mining/the_statue_of_liberty
# pack:mining/the_way_to_spawn
# pack:mining/this_dirt_is_dirtier
# pack:mining/this_is_mine_now
# pack:mining/weve_broken_our_last_shovel
# pack:mining/whats_the_time_mr_wolf
# pack:mining/where_are_all_your_clothes
# pack:mining/youll_never_take_me_alive_copper
# pack:monsters/anti_air
# pack:monsters/aww_man
# pack:monsters/a_watery_grave
# pack:monsters/baby_baby_baby_noo
# pack:monsters/basketblock_championship
# pack:monsters/because_im_aquaman
# pack:monsters/blast_shield
# pack:monsters/blind_stare
# pack:monsters/bogged_down
# pack:monsters/boned
# pack:monsters/bone_to_party
# pack:monsters/camouflage
# pack:monsters/captain_etho
# pack:monsters/controlled_detonation
# pack:monsters/creeper_killer
# pack:monsters/creepy_heads
# pack:monsters/custom_boss_fight
# pack:monsters/dead_dont_die
# pack:monsters/dead_really_dont_die
# pack:monsters/desert_nomad
# pack:monsters/dungeon_crawler
# pack:monsters/enderman_destroyer
# pack:monsters/ender_worm
# pack:monsters/ew_ew_ew
# pack:monsters/family_reunion
# pack:monsters/freezing
# pack:monsters/frosty
# pack:monsters/gelatinous_cube
# pack:monsters/handsome_jack
# pack:monsters/hell_hunter
# pack:monsters/house_of_freaks
# pack:monsters/impossible
# pack:monsters/iron_belly
# pack:monsters/keep_your_distance
# pack:monsters/maximum_resistance
# pack:monsters/melting
# pack:monsters/miracle_drink
# pack:monsters/mollusc_man
# pack:monsters/night_runner
# pack:monsters/not_afraid_of_heights
# pack:monsters/now_thats_a_lot_of_damage
# pack:monsters/oh_no_guys_im_oozing
# pack:monsters/ooh_baby
# pack:monsters/paleontologist
# pack:monsters/phantom_slayer
# pack:monsters/plane_walker
# pack:monsters/poisonous_ew
# pack:monsters/poison_dart
# pack:monsters/poultry_boy
# pack:monsters/pupil_poppers
# pack:monsters/ricochet_swoop
# pack:monsters/root
# pack:monsters/skeleton_smiter
# pack:monsters/slime_squisher
# pack:monsters/spider_skeleton
# pack:monsters/spider_smasher
# pack:monsters/spooky_skeleton
# pack:monsters/spooky_skulls
# pack:monsters/stealth_is_optional
# pack:monsters/still_talking
# pack:monsters/taste_of_your_own_medicine
# pack:monsters/tele_morph
# pack:monsters/termite_control
# pack:monsters/there_has_to_be_another_way
# pack:monsters/the_ender_of_ender
# pack:monsters/the_ghastly_eyes
# pack:monsters/the_phantom_menace
# pack:monsters/the_undead_cavalry
# pack:monsters/trampoline
# pack:monsters/trick_or_treat
# pack:monsters/tridented_shield
# pack:monsters/void_ender
# pack:monsters/warden_frostbite
# pack:monsters/well_handle_this
# pack:monsters/what_a_creep
# pack:monsters/witch
# pack:monsters/zombie_slayer
# pack:nether/anchorman
# pack:nether/ancient_restoration
# pack:nether/astrobrute
# pack:nether/a_piglins_best_friend
# pack:nether/a_soul_for_a_soul
# pack:nether/basis_of_brewing
# pack:nether/beacon_overlord
# pack:nether/blaze_extinguisher
# pack:nether/bobbleheads
# pack:nether/bring_down_the_beast
# pack:nether/brute_force
# pack:nether/burnt_right_into_your_soul
# pack:nether/cultural_misunderstandings
# pack:nether/dark_ages
# pack:nether/decaying_beauty
# pack:nether/diamonds_are_not_forever
# pack:nether/dont_blink
# pack:nether/electrifying_alliance
# pack:nether/enders_chest
# pack:nether/et_tu_brute
# pack:nether/fire_blast_shield
# pack:nether/fool_me_twice
# pack:nether/from_whence_it_came
# pack:nether/get_a_lode_of_this
# pack:nether/ghast_slayer
# pack:nether/giant_floating_jellyfish
# pack:nether/giddy_up
# pack:nether/gilded_miner
# pack:nether/gilty
# pack:nether/glowstone_miner
# pack:nether/glows_in_the_dark
# pack:nether/hells_bells
# pack:nether/hell_botanist
# pack:nether/high_temperature_fluid_monster
# pack:nether/holy_scrap
# pack:nether/hot_reels
# pack:nether/hot_spring
# pack:nether/hung_drawn_and_bartered
# pack:nether/im_in_lava_with_you
# pack:nether/inception
# pack:nether/instant_mining
# pack:nether/i_am_root
# pack:nether/jenga
# pack:nether/legend_of_hell_chicken_riders
# pack:nether/let_me_out
# pack:nether/light_show
# pack:nether/limbo_walker
# pack:nether/lodes_of_applications
# pack:nether/ludicrous_speed
# pack:nether/magma_cube_squisher
# pack:nether/master_netherite_miner
# pack:nether/moar_upgraded_tools
# pack:nether/netherite_mad_lad
# pack:nether/netherite_miner
# pack:nether/nether_rock_collection
# pack:nether/nugget_in_a_biscuit
# pack:nether/piglin_peril
# pack:nether/polar_opposites
# pack:nether/quicksand
# pack:nether/roadhog
# pack:nether/seeing_stars
# pack:nether/soul_runnings
# pack:nether/spreading_corruption
# pack:nether/stem_research
# pack:nether/stepping_on_legos
# pack:nether/the_descent
# pack:nether/the_hunt_begins
# pack:nether/the_nethers_shield
# pack:nether/the_struggle_nether_ends
# pack:nether/the_tribal_snouts
# pack:nether/this_ones_mine
# pack:nether/time_to_fire_back
# pack:nether/time_to_upgrade
# pack:nether/twisted
# pack:nether/welcome_to_warp_zone
# pack:nether/we_got_a_live_one
# pack:nether/what_about_corruption_planks
# pack:nether/what_a_fungi
# pack:nether/when_hoglins_breed
# pack:nether/when_piglins_fly
# pack:nether/whole_hog
# pack:nether/wub_wub_wub
# pack:nether/zork_chop
# pack:potion/a_furious_test_subject
# pack:potion/a_much_more_doable_challenge
# pack:potion/a_weak_brew
# pack:potion/death_by_magic
# pack:potion/failed_concoctions
# pack:potion/final_shout
# pack:potion/furious_ammunition
# pack:potion/gas
# pack:potion/gas_bomb
# pack:potion/hopping_mad
# pack:potion/hyper_healing
# pack:potion/imbued_projectiles
# pack:potion/mad_scientist
# pack:potion/marine_marauder
# pack:potion/medic
# pack:potion/nocturnal
# pack:potion/noxious_fumes
# pack:potion/performance_enhancing_drugs
# pack:potion/root
# pack:potion/secret_of_the_ooze
# pack:potion/stayin_frosty
# pack:potion/stealth_takedown
# pack:potion/super_strength
# pack:potion/tank
# pack:potion/the_invisible_player
# pack:potion/true_feather_falling
# pack:redstone/all_aboard
# pack:redstone/bling_plate
# pack:redstone/calibration_sensation
# pack:redstone/cataclyst
# pack:redstone/click
# pack:redstone/comparing_comparator
# pack:redstone/craftception
# pack:redstone/dispense_with_this
# pack:redstone/electric_rails
# pack:redstone/engineer
# pack:redstone/factorio
# pack:redstone/fuel_engine
# pack:redstone/leveraging_synergy
# pack:redstone/master_engineer
# pack:redstone/metal_plate
# pack:redstone/mobile_explosion
# pack:redstone/monstrous_music
# pack:redstone/monstrous_sacrifices
# pack:redstone/moving_moving_storage
# pack:redstone/moving_parts
# pack:redstone/moving_storage
# pack:redstone/mozart
# pack:redstone/noteworthy
# pack:redstone/observer_buddy
# pack:redstone/on_a_rail
# pack:redstone/powerful_light
# pack:redstone/pressure_detector
# pack:redstone/quartz_miner
# pack:redstone/quirky_quartz
# pack:redstone/railwayman
# pack:redstone/repeating_repeater
# pack:redstone/root
# pack:redstone/sculker_box
# pack:redstone/solar_power
# pack:redstone/space_dropper
# pack:redstone/space_hopper
# pack:redstone/sticky_parts
# pack:redstone/take_notes
# pack:redstone/target_acquired
# pack:redstone/target_practise
# pack:redstone/the_block_of_eternal_screaming
# pack:redstone/the_incredible_sculk
# pack:redstone/travelling_bard
# pack:redstone/tripping_over
# pack:redstone/troll_chest
# pack:redstone/under_pressure
# pack:redstone/vibe_check
# pack:redstone/we_have_liftoff
# pack:statistics/65_hours_of_walking
# pack:statistics/ancient_kung_fu_master
# pack:statistics/big_spender
# pack:statistics/black_belt_ninja
# pack:statistics/bloodthirsty
# pack:statistics/boing_boing
# pack:statistics/cupid
# pack:statistics/elderly_enchanter
# pack:statistics/food_glorious_food
# pack:statistics/frequent_flyer
# pack:statistics/giga_xp_grinder
# pack:statistics/global_railway_network
# pack:statistics/happy_new_year
# pack:statistics/horse_training
# pack:statistics/i_enjoy_long_walks_and_playing_minecraft
# pack:statistics/i_heart_chests
# pack:statistics/i_like_trains
# pack:statistics/journeyman_enchanter
# pack:statistics/jumping_jacks
# pack:statistics/kill_or_be_killed
# pack:statistics/laps_in_the_pool
# pack:statistics/level_up
# pack:statistics/lightning_mcpig
# pack:statistics/loot_em
# pack:statistics/luxury_cruise
# pack:statistics/marathon
# pack:statistics/minecart_rider
# pack:statistics/mob_hunter
# pack:statistics/more_for_me
# pack:statistics/natural_sprinter
# pack:statistics/novice_enchanter
# pack:statistics/olympic_athlete
# pack:statistics/olympic_gold_medallist
# pack:statistics/om_nom_nom
# pack:statistics/out_for_a_stroll
# pack:statistics/overlevelling
# pack:statistics/passing_the_time
# pack:statistics/pig_training
# pack:statistics/pirate_captain
# pack:statistics/root
# pack:statistics/sailor_of_the_seven_seas
# pack:statistics/scourge_of_the_west
# pack:statistics/sheriff_firearm
# pack:statistics/sneaky_snitch
# pack:statistics/snout_500
# pack:statistics/spring_in_your_step
# pack:statistics/stonks
# pack:statistics/supersonic
# pack:statistics/take_to_the_skies
# pack:statistics/taking_it_in_stride
# pack:statistics/the_first_night
# pack:statistics/the_haggler
# pack:statistics/the_parrots_and_the_bats
# pack:statistics/this_ride_is_lit_yo
# pack:statistics/two_by_two
# pack:statistics/who_needs_boats
# pack:statistics/who_needs_cars
# pack:statistics/xp_grinder
# pack:statistics/your_legs_must_be_tired
# pack:statistics/yum_yum_yummo
# pack:technical/a_wizards_breakfast
# pack:technical/a_wizards_breakfast_fail
# pack:technical/bacap_branch_end
# pack:technical/below_void
# pack:technical/big_cheater
# pack:technical/branch1_end
# pack:technical/branch2_end
# pack:technical/branch3_end
# pack:technical/branch4_end
# pack:technical/branch5_end
# pack:technical/branch6_end
# pack:technical/branch7_end
# pack:technical/branch8_end
# pack:technical/castaway_fail
# pack:technical/castaway_start
# pack:technical/cheater2
# pack:technical/cheater3
# pack:technical/consume_food
# pack:technical/consume_food_null
# pack:technical/divers_dozen_count
# pack:technical/factorio_craft
# pack:technical/fail_dragon_vs
# pack:technical/feed_parrot_cookie
# pack:technical/give_piglin_gold
# pack:technical/goat_horn_use
# pack:technical/goat_simulator_check
# pack:technical/inventory_changed
# pack:technical/just_keeps_going_fail
# pack:technical/just_keeps_going_start
# pack:technical/kill_dragon
# pack:technical/kill_wither
# pack:technical/lucky_break_check
# pack:technical/on_a_rail_start
# pack:technical/open_loot_chest
# pack:technical/place_painting
# pack:technical/respawn_dragon
# pack:technical/respawn_wither
# pack:technical/return_from_void
# pack:technical/riddle_eighth_line
# pack:technical/riddle_fifth_line
# pack:technical/riddle_first_line
# pack:technical/riddle_fourth_line
# pack:technical/riddle_ninth_line
# pack:technical/riddle_second_line
# pack:technical/riddle_seventh_line
# pack:technical/riddle_sixth_line
# pack:technical/riddle_tenth_line
# pack:technical/riddle_third_line
# pack:technical/sound_the_alarm_check
# pack:technical/spawn_perfect_all
# pack:technical/spawn_perfect_one
# pack:technical/stat_branch1_mid
# pack:technical/stat_branch2_mid
# pack:technical/stat_branch3_mid
# pack:technical/stat_branch4_mid
# pack:technical/stat_branch5_mid
# pack:technical/stat_branch6_mid
# pack:technical/stat_branch7_mid
# pack:technical/stat_branch8_mid
# pack:technical/stat_branch9_mid
# pack:technical/unending_hell_end
# pack:technical/vault_hunter_count
# pack:technical/whack_a_mole_count
# pack:technical/you_are_a_big_cheater
# pack:weaponry/artillery
# pack:weaponry/axeman
# pack:weaponry/a_snowballs_chance_in_hell
# pack:weaponry/backfire
# pack:weaponry/bombs_away
# pack:weaponry/bow_spammer
# pack:weaponry/demolitions_expert
# pack:weaponry/diemonds
# pack:weaponry/egging_dude
# pack:weaponry/expelliarmus
# pack:weaponry/explosive_fire
# pack:weaponry/fireworks_display
# pack:weaponry/flying_colors
# pack:weaponry/half_heart_life
# pack:weaponry/indiana_jones
# pack:weaponry/inspector_gadget
# pack:weaponry/its_time_consuming
# pack:weaponry/king_of_the_sea
# pack:weaponry/loser
# pack:weaponry/master_shieldsman
# pack:weaponry/multiclassed
# pack:weaponry/my_eyes
# pack:weaponry/nice_to_mace_you
# pack:weaponry/pig_fishing_tournament
# pack:weaponry/point_blank
# pack:weaponry/poseidon_vs_hades
# pack:weaponry/pyrotechnic
# pack:weaponry/revenge
# pack:weaponry/rock_paper_shears
# pack:weaponry/root
# pack:weaponry/shield_luck
# pack:weaponry/shovel_knight
# pack:weaponry/sir_knight
# pack:weaponry/slapfish
# pack:weaponry/snowball_fight
# pack:weaponry/spleaf
# pack:weaponry/that_is_so_fletch
# pack:weaponry/theres_yolk_on_my_head
# pack:weaponry/there_it_goes
# pack:weaponry/the_aquatic_hunter
# pack:weaponry/the_mighty_hunter
# pack:weaponry/viking
# pack:weaponry/warden_extinction
# pack:weaponry/when_pigs_finally_fly
# pack:weaponry/who_ya_gonna_call
# pack:weaponry/x_bow

# %%
# For generating a list of all the items, and their mapping to adv
stack_blocks = set(adv_data["blazeandcave:challenges/stack_all_the_blocks"]['criteria'].keys())
stack_items = set(adv_data["blazeandcave:challenges/stack_all_the_items"]['criteria'].keys())

blocks = set(adv_data["blazeandcave:challenges/all_the_blocks"]['criteria'].keys())
items = set(adv_data["blazeandcave:challenges/all_the_items"]['criteria'].keys())

print(len(stack_items), len(stack_blocks), len(stack_items.union(stack_blocks)))
print(len(items), len(blocks), len(items.union(blocks)))
print(items.union(blocks).difference(stack_items.union(stack_blocks)))
all_items = items.union(blocks)
stack_all_items = stack_items.union(stack_blocks)

everything = all_items.union(stack_all_items)

item_to_adv = []

for item in list(everything):
    adv = None
    if item in stack_blocks:
        adv = "blazeandcave:challenges/stack_all_the_blocks"
    elif item in stack_items:
        adv = "blazeandcave:challenges/stack_all_the_items"
    elif item in blocks:
        adv = "blazeandcave:challenges/all_the_blocks"
    elif item in items:
        adv = "blazeandcave:challenges/all_the_items"
    item_to_adv.append([item, adv])

item_to_adv = sorted(item_to_adv,  key=lambda x: x[0])

with open('output/item_to_adv.csv', 'w', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter='\t')
    writer.writerows(item_to_adv)
# Out:
# 320 902 1222
# 362 910 1272
# {'arms_up_pottery_sherd', 'dune_armor_trim', 'eye_armor_trim', 'coast_armor_trim', 'shaper_armor_trim', 'scrape_pottery_sherd', 'plenty_pottery_sherd', 'vex_armor_trim', 'angler_pottery_sherd', 'flow_armor_trim_smithing_template', 'netherite_block', 'danger_pottery_sherd', 'wild_armor_trim', 'heart_pottery_sherd', 'tall_grass', 'bolt_armor_trim_smithing_template', 'shelter_pottery_sherd', 'spire_armor_trim', 'snout_armor_trim', 'silence_armor_trim', 'mourner_pottery_sherd', 'burn_pottery_sherd', 'sentry_armor_trim', 'heavy_core', 'deepslate_emerald_ore', 'brewer_pottery_sherd', 'ward_armor_trim', 'guster_pottery_sherd', 'sheaf_pottery_sherd', 'explorer_pottery_sherd', 'flow_pottery_sherd', 'recovery_compass', 'suspicious_sand', 'wayfinder_armor_trim', 'prize_pottery_sherd', 'tide_armor_trim', 'host_armor_trim', 'heartbreak_pottery_sherd', 'miner_pottery_sherd', 'snort_pottery_sherd', 'blade_pottery_sherd', 'howl_pottery_sherd', 'netherite_upgrade', 'suspicious_gravel', 'dragon_egg', 'rib_armor_trim', 'raiser_armor_trim', 'archer_pottery_sherd', 'friend_pottery_sherd', 'skull_pottery_sherd', 'large_fern'}

# %%
# Adding column for stack sizes
with open('data/pack/data/blazeandcave/advancement/challenges/stack_all_the_blocks.json') as f:
    stack_blocks_json = json.load(f)['criteria']

with open('data/pack/data/blazeandcave/advancement/challenges/stack_all_the_items.json') as f:
    stack_items_json = json.load(f)['criteria']

item_adv_stacksize = []
for item, adv in item_to_adv:
    stacksize = 1
    try:
        if item in stack_blocks_json:
            stacksize = stack_blocks_json[item]['conditions']['items'][0]['count']
        elif item in stack_items_json:
            stacksize = stack_items_json[item]['conditions']['items'][0]['count']
    except KeyError:
        pass
    name = ' '.join(word.capitalize() for word in item.split('_'))
    item_adv_stacksize.append([name, item, adv, stacksize])

item_adv_stacksize = sorted(item_adv_stacksize, key=lambda x: x[0])

with open('output/item_adv_stacksize.csv', 'w', newline='') as csv_file:
    writer = csv.writer(csv_file, delimiter='\t')
    writer.writerows(item_adv_stacksize)

# %%
adv_col = []
with open('output/adv_col.csv') as f:
    reader = csv.reader(f, delimiter='\t')
    for row in reader:
        adv_col.append(row)

adv_to_cell = []
for i, adv in enumerate(adv_col):
    adv_to_cell.append([adv, f'E{i}'])

# %%
reference = '''IF(ISBLANK(A3), {"","",""}, {{A3, "Adv/Item", "Description"};IFERROR({FILTER({'All Items/Blocks'!$C$2:$D, 'All Items/Blocks'!$G$2:$G}, 'All Items/Blocks'!$B$2:$B=A3);{"","",""}}, {"", "", ""})})'''
full_string = reference

for i in range(20):
    row = i + 4
    full_string += ';' + reference.replace("A3", f'A{row}')

print(full_string)
# Out:
# IF(ISBLANK(A3), {"","",""}, {{A3, "Adv/Item", "Description"};IFERROR({FILTER({'All Items/Blocks'!$C$2:$D, 'All Items/Blocks'!$G$2:$G}, 'All Items/Blocks'!$B$2:$B=A3);{"","",""}}, {"", "", ""})});IF(ISBLANK(A4), {"","",""}, {{A4, "Adv/Item", "Description"};IFERROR({FILTER({'All Items/Blocks'!$C$2:$D, 'All Items/Blocks'!$G$2:$G}, 'All Items/Blocks'!$B$2:$B=A4);{"","",""}}, {"", "", ""})});IF(ISBLANK(A5), {"","",""}, {{A5, "Adv/Item", "Description"};IFERROR({FILTER({'All Items/Blocks'!$C$2:$D, 'All Items/Blocks'!$G$2:$G}, 'All Items/Blocks'!$B$2:$B=A5);{"","",""}}, {"", "", ""})});IF(ISBLANK(A6), {"","",""}, {{A6, "Adv/Item", "Description"};IFERROR({FILTER({'All Items/Blocks'!$C$2:$D, 'All Items/Blocks'!$G$2:$G}, 'All Items/Blocks'!$B$2:$B=A6);{"","",""}}, {"", "", ""})});IF(ISBLANK(A7), {"","",""}, {{A7, "Adv/Item", "Description"};IFERROR({FILTER({'All Items/Blocks'!$C$2:$D, 'All Items/Blocks'!$G$2:$G}, 'All Items/Blocks'!$B$2:$B=A7);{"","",""}}, {"", "", ""})});IF(ISBLANK(A8), {"","",""}, {{A8, "Adv/Item", "Description"};IFERROR({FILTER({'All Items/Blocks'!$C$2:$D, 'All Items/Blocks'!$G$2:$G}, 'All Items/Blocks'!$B$2:$B=A8);{"","",""}}, {"", "", ""})});IF(ISBLANK(A9), {"","",""}, {{A9, "Adv/Item", "Description"};IFERROR({FILTER({'All Items/Blocks'!$C$2:$D, 'All Items/Blocks'!$G$2:$G}, 'All Items/Blocks'!$B$2:$B=A9);{"","",""}}, {"", "", ""})});IF(ISBLANK(A10), {"","",""}, {{A10, "Adv/Item", "Description"};IFERROR({FILTER({'All Items/Blocks'!$C$2:$D, 'All Items/Blocks'!$G$2:$G}, 'All Items/Blocks'!$B$2:$B=A10);{"","",""}}, {"", "", ""})});IF(ISBLANK(A11), {"","",""}, {{A11, "Adv/Item", "Description"};IFERROR({FILTER({'All Items/Blocks'!$C$2:$D, 'All Items/Blocks'!$G$2:$G}, 'All Items/Blocks'!$B$2:$B=A11);{"","",""}}, {"", "", ""})});IF(ISBLANK(A12), {"","",""}, {{A12, "Adv/Item", "Description"};IFERROR({FILTER({'All Items/Blocks'!$C$2:$D, 'All Items/Blocks'!$G$2:$G}, 'All Items/Blocks'!$B$2:$B=A12);{"","",""}}, {"", "", ""})});IF(ISBLANK(A13), {"","",""}, {{A13, "Adv/Item", "Description"};IFERROR({FILTER({'All Items/Blocks'!$C$2:$D, 'All Items/Blocks'!$G$2:$G}, 'All Items/Blocks'!$B$2:$B=A13);{"","",""}}, {"", "", ""})});IF(ISBLANK(A14), {"","",""}, {{A14, "Adv/Item", "Description"};IFERROR({FILTER({'All Items/Blocks'!$C$2:$D, 'All Items/Blocks'!$G$2:$G}, 'All Items/Blocks'!$B$2:$B=A14);{"","",""}}, {"", "", ""})});IF(ISBLANK(A15), {"","",""}, {{A15, "Adv/Item", "Description"};IFERROR({FILTER({'All Items/Blocks'!$C$2:$D, 'All Items/Blocks'!$G$2:$G}, 'All Items/Blocks'!$B$2:$B=A15);{"","",""}}, {"", "", ""})});IF(ISBLANK(A16), {"","",""}, {{A16, "Adv/Item", "Description"};IFERROR({FILTER({'All Items/Blocks'!$C$2:$D, 'All Items/Blocks'!$G$2:$G}, 'All Items/Blocks'!$B$2:$B=A16);{"","",""}}, {"", "", ""})});IF(ISBLANK(A17), {"","",""}, {{A17, "Adv/Item", "Description"};IFERROR({FILTER({'All Items/Blocks'!$C$2:$D, 'All Items/Blocks'!$G$2:$G}, 'All Items/Blocks'!$B$2:$B=A17);{"","",""}}, {"", "", ""})});IF(ISBLANK(A18), {"","",""}, {{A18, "Adv/Item", "Description"};IFERROR({FILTER({'All Items/Blocks'!$C$2:$D, 'All Items/Blocks'!$G$2:$G}, 'All Items/Blocks'!$B$2:$B=A18);{"","",""}}, {"", "", ""})});IF(ISBLANK(A19), {"","",""}, {{A19, "Adv/Item", "Description"};IFERROR({FILTER({'All Items/Blocks'!$C$2:$D, 'All Items/Blocks'!$G$2:$G}, 'All Items/Blocks'!$B$2:$B=A19);{"","",""}}, {"", "", ""})});IF(ISBLANK(A20), {"","",""}, {{A20, "Adv/Item", "Description"};IFERROR({FILTER({'All Items/Blocks'!$C$2:$D, 'All Items/Blocks'!$G$2:$G}, 'All Items/Blocks'!$B$2:$B=A20);{"","",""}}, {"", "", ""})});IF(ISBLANK(A21), {"","",""}, {{A21, "Adv/Item", "Description"};IFERROR({FILTER({'All Items/Blocks'!$C$2:$D, 'All Items/Blocks'!$G$2:$G}, 'All Items/Blocks'!$B$2:$B=A21);{"","",""}}, {"", "", ""})});IF(ISBLANK(A22), {"","",""}, {{A22, "Adv/Item", "Description"};IFERROR({FILTER({'All Items/Blocks'!$C$2:$D, 'All Items/Blocks'!$G$2:$G}, 'All Items/Blocks'!$B$2:$B=A22);{"","",""}}, {"", "", ""})});IF(ISBLANK(A23), {"","",""}, {{A23, "Adv/Item", "Description" ...

# %%
import os
import json
import csv
import re

'''
    Reads all the advancement criterias and stores it
'''

every_adv = []
with open('output/adv_col.csv', 'r') as f:
    reader = csv.reader(f)
    for row in reader:
        every_adv.append(row[0])

with open('data/advancements.json', 'r') as f:
    everything_data = json.load(f)

def parse_path(adv_path):
    adv_info = re.match('(\w+):(\w+)\/(\w+)', adv_path)
    return adv_info.groups()

datapack_dir = 'data/pack/data'
adv_reqs = {}
for adv_path in every_adv:
    folder, tab, adv = parse_path(adv_path)
    file_path = os.path.join(datapack_dir, folder, 'advancement', tab, adv) + '.json'
    with open(file_path, 'r') as f:
        adv_data = json.load(f)
        if 'requirements' in adv_data.keys():
            adv_reqs[adv_path] = list(adv_data['requirements'])
        else:
            adv_reqs[adv_path] = list(everything_data[adv_path]['criteria'].keys())

with open('output/adv_criteria_requirements.json', 'w', encoding='utf-8') as f:
    json.dump(adv_reqs, f)

# %%
mobs_list = []
mobs_dict = defaultdict(lambda:[])
with open('mobs.json', 'r') as f:
    mobs = json.load(f)
    for i in mobs:
        mobs_list.append(i)

with open('output/adv_criteria_requirements.json', 'r') as f:
    advs = json.load(f)
    for i in advs:
        for j in mobs_list:
            if j in advs[i] or "minecraft:" + j in advs[i]:
                mobs_dict[j].append(i)

with open('output/mobs.csv', 'w', newline='') as f:
    for mob in mobs_dict:
        f.write(mob + "\n")
        for adv in mobs_dict[mob]:
            f.write(adv + "\n")

with open('output/mobs.txt', 'w', newline='') as f:
    for mob in mobs_dict:
        f.write(mob + "\n")

print(len(mobs_dict))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 3
#       1 mobs_list = []
#       2 mobs_dict = defaultdict(lambda:[])
# ----> 3 with open('mobs.json', 'r') as f:
#       4     mobs = json.load(f)
#       5     for i in mobs:
#
# File c:\Users\andre\Documents\bac-tracker\.venv\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mobs.json'

# %%
try:
    with open("data\\blazeandcave\\advancement\\animal\\a_horse_in_shining_armor.json", 'r') as f:
        # If this fails Cavinator left a json error (yay!)
        # Just navigate to the most recent json file and fix
        data = json.load(f)
        print(data['display']['title']['translate'])
        print(data['display']['icon']['id'][10:])
except KeyError:
    display_name = "NOT AN ADVANCEMENT"
# Out:
# A Horse in Shining Armor
# diamond_horse_armor
